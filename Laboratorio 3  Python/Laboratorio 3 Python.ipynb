# %% [markdown]
# ###  Laboratorio #3
# ####  Andrés Alberto Peña
# ####  Ciencia de Datos con Python

# %%
import numpy as np
import sys 
import pandas as pd
import matplotlib.pyplot as plt
import math
import datetime

# %% [markdown]
# ##### 1) ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
array = [False] * 1000
tamaño = sys.getsizeof(array)
print(f"El tamaño del array de booleanos es de {tamaño} bytes")
# Out:
# El tamaño del array de booleanos es de 8056 bytes

# %% [markdown]
# ##### 2) Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
pares = [numero for numero in range(100, 0, -2)]
ultimos_10 = pares[-10:]

print("Los últimos 10 elementos del array son:", ultimos_10)
# Out:
# Los últimos 10 elementos del array son: [20, 18, 16, 14, 12, 10, 8, 6, 4, 2]

# %% [markdown]
# ##### 3)  Dado el array
# 2 4 5 6
#
# 0 3 7 4
#
# 8 8 5 2
#
# 1 5 6 1
#
# ##### Seleccione con una instrucción el subarray de elementos
# 0 3 7 4
#
# ##### Después, seleccione el subarray de elementos
# 2 5
#
# 8 5

# %%
ejercicio = np.array([[2, 4, 5, 6], [0, 3, 7, 4], [8, 8, 5, 2], [1, 5, 6, 1]])

sub_1 = ejercicio[1, 1:5] # el primer subarray
sub_2 = ejercicio[0:3:2, 1:3] # el segundo subarray

print("El primer subarray es:", sub_1)
print("El segundo subarray es:", sub_2)
# Out:
# El primer subarray es: [3 7 4]
# El segundo subarray es: [[4 5]
#  [8 5]]

# %% [markdown]
# ##### 4. Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
a = [1, 4, 2, 7]
b = [1, 3, 2, 9]

diferencia = np.subtract(a, b)
media = np.mean(diferencia)

print("La media aritmética de la diferencia es:", media)
# Out:
# La media aritmética de la diferencia es: -0.25

# %% [markdown]
# ##### 5. Tengo valores de cordenadas (x, y) en las columnas del array
# .  1.33  4.5
# .  30.0  10.7
# .  70.2  0.5
#
# ##### Agregue a este array las coordenadas (37.1, -3.6).   Muestre en pantalla las dimensiones del nuevo array.

# %%
a = np.array([[1.33, 4.5], [30.0, 10.7], [70.2, 0.5]])
a_1 = np.append(a, [[37.1, -3.6]], axis=0)

print("El nuevo array es:", a_1)
print("Las dimensiones del nuevo array son:", a_1.shape)
# Out:
# El nuevo array es: [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]
#  [37.1  -3.6 ]]
# Las dimensiones del nuevo array son: (4, 2)

# %% [markdown]
# ##### 6) Copie el array del ejercicio anterior.)Traspóngalo
# ##### Agregue ahora dos nuevos pares de coordenadas: (10.8,3.0) y (35.8, 12.0).

# %%
b = a.T
nueva_columna = np.array([[10.8, 35.8], [3.0, 12.0]])
b = np.hstack((b, nueva_columna))
print(b)
# Out:
# [[ 1.33 30.   70.2  10.8  35.8 ]
#  [ 4.5  10.7   0.5   3.   12.  ]]

# %% [markdown]
# #### Parte 2: Exploración y Minería de Datos:
# ##### Con el dataset nucleospoblacion.csv adjunto al laboratorio, luego responda las siguientes preguntas usando pandas y matplotlib.

# %%
# Definir ruta del archivo
filepath = r"D:\Data Science\Maestria UG\Año 1\Python\Lab_3\Lab_3\NucleosPoblacion.csv"
   
# leer y definir el dataframe
df = pd.read_csv(filepath)
   
# imprimir 10 primeras columnas
print(df.head())
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %% [markdown]
# ##### Pregunta 1:  ¿Cuántos Municipios tienen más de 100000 habitantes?.

# %%
poblacion_1000 = df.apply(lambda x: x['Poblacion'] > 1000, axis=1).sum()
print(f'El numero de municipios con una población >1000 es: {poblacion_1000}' )
# Out:
# El numero de municipios con una población >1000 es: 852

# %% [markdown]
# #### 2) Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayo y responda:

# %%
#por_poblacion = df['Poblacion'].sort_values
#por_poblacion()

df_ordenado = df.sort_values(by='Poblacion')
df_ordenado
# Out:
#      FID  OBJECTID           Texto  Poblacion  CodMun       Municipio  \
# 307  307       308       Zumarraga    10037.0   20080       Zumarraga
# 115  115       116  Caldas de Reis    10045.0   36005  Caldas de Reis
# 168  168       169         Amurrio    10050.0    1002         Amurrio
# 746  746       747  Premià de Dalt    10064.0    8230  Premià de Dalt
# 525  525       526           Buñol    10077.0   46077           Buñol
# ..   ...       ...             ...        ...     ...             ...
# 591  591       592        Zaragoza   675121.0   50297        Zaragoza
# 492  492       493         Sevilla   704198.0   41091         Sevilla
# 561  561       562        Valencia   809267.0   46250        Valencia
# 623  623       624       Barcelona  1619337.0    8019       Barcelona
# 355  355       356          Madrid  3273049.0   28079          Madrid
#
#      CodProvin          Provincia         X          Y
# 307         20          Guipúzcoa -2.323006  43.087693
# ...

# %%
plt.bar(df_ordenado["Municipio"], df_ordenado["Poblacion"])
# Rotar la etiqueta del eje X
plt.xticks(rotation=90)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ##### a. ¿Cuál es la segunda ciudad más poblada?

# %%
segunda_ciudad = df_ordenado.iloc[-2]["Municipio"]
print("La segunda ciudad más poblada es", segunda_ciudad)
# Out:
# La segunda ciudad más poblada es Barcelona

# %% [markdown]
# ##### b. ¿Qué posición ocupa Granada?

# %%
ranking_granada = df_ordenado[df_ordenado["Municipio"] == "Granada"].index[0] + 1
print("Granada ocupa la posición", ranking_granada, "en el ranking de ciudades por población.")
# Out:
# Granada ocupa la posición 273 en el ranking de ciudades por población.

# %%
# Seleccionar el municipio situado más al norte
municipio_norte = df.loc[df["Y"].idxmax()]
print(municipio_norte)
print("")
# Obtener el nombre del municipio, la provincia y la población
nombre_municipio_norte = municipio_norte["Municipio"]
provincia_municipio_norte = municipio_norte["Provincia"]
poblacion_municipio_norte = municipio_norte["Poblacion"]

print("El municipio situado más al norte es", nombre_municipio_norte, "que pertenece a la provincia de", provincia_municipio_norte, "y tiene una población de", poblacion_municipio_norte, "habitantes.")
# Out:
# FID                104
# OBJECTID           105
# Texto          Viveiro
# Poblacion      16211.0
# CodMun           27066
# Municipio      Viveiro
# CodProvin           27
# Provincia         Lugo
# X            -7.588768
# Y            43.625578
# Name: 104, dtype: object
#
# El municipio situado más al norte es Viveiro que pertenece a la provincia de Lugo y tiene una población de 16211.0 habitantes.

# %% [markdown]
# ##### 5) Obtener estadísticas de la población de los municipios de la provincia de Granada

# %%
poblacion_granada = df.loc[df["Provincia"] == "Granada"]["Poblacion"]
media_poblacion_granada = poblacion_granada.mean()
mediana_poblacion_granada = poblacion_granada.median()
desviacion_poblacion_granada = poblacion_granada.std()
max_poblacion_granada = poblacion_granada.max()
min_poblacion_granada = poblacion_granada.min()
print("Estadísticas de población para los municipios de Granada:")
print("Media:", media_poblacion_granada)
print("Mediana:", mediana_poblacion_granada)
print("Desviación estándar:", desviacion_poblacion_granada)
print("Valor máximo:", max_poblacion_granada)
print("Valor mínimo:", min_poblacion_granada)
# Out:
# Estadísticas de población para los municipios de Granada:
# Media: 30217.85
# Mediana: 17526.0
# Desviación estándar: 50355.49171459277
# Valor máximo: 239154.0
# Valor mínimo: 10386.0

# %% [markdown]
# ##### 6) Realizar histograma de la población de los Municipios para cada una de las provincias

# %%
provincias = df["Provincia"].unique()
for provincia in provincias:
    poblacion = df.loc[df["Provincia"] == provincia]["Poblacion"]
    plt.hist(poblacion, bins=50)
    plt.title("Histograma de población para " + provincia)
    plt.xlabel("Población")
    plt.ylabel("Frecuencia")
    plt.show()

# %% [markdown]
# ##### 8) Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero.

# %%
# Filtrar los datos para incluir solo los municipios de la provincia de Madrid
madrid_df = df[df['Provincia'] == 'Madrid']

# Calcular la distancia entre cada municipio y Madrid utilizando la fórmula de la distancia entre dos puntos
distancias = {}
for index, row in df.iterrows():
    if row['Provincia'] != 'Madrid':
        x1, y1 = madrid_df.iloc[0]['X'], madrid_df.iloc[0]['Y']
        x2, y2 = row['X'], row['Y']
        distancia = math.sqrt((x2-x1)**2 + (y2-y1)**2)
        distancias[row['Municipio']] = distancia

# Encontrar el municipio más cercano y el más lejano a Madrid basándonos en las distancias calculadas
municipio_mas_cercano = min(distancias, key=distancias.get)
municipio_mas_lejano = max(distancias, key=distancias.get)

# Imprimir los resultados
print(f"El municipio más cercano a Madrid es {municipio_mas_cercano}, con una distancia de {distancias[municipio_mas_cercano]} km.")
print(f"El municipio más lejano a Madrid es {municipio_mas_lejano}, con una distancia de {distancias[municipio_mas_lejano]} km.")
# Out:
# El municipio más cercano a Madrid es Azuqueca de Henares, con una distancia de 0.13866952486797113 km.
# El municipio más lejano a Madrid es Los Llanos de Aridane, con una distancia de 18.743336896244124 km.

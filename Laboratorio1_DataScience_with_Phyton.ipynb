# %% [markdown]
# # El modelo de GIT:  Control de Versiones
#
# ## Tarea 1:  Ciencia de Datos en Python
#
# ### Andrés Alberto Peña -  Carné: 23004061

# %% [markdown]
# A continuación se presenta un resumen de los puntos presentados durante el video que se solicito ver en clase,  el fue visto en el siguiente enlace
#
# https://missing.csail.mit.edu/2020/version-control/
#
# Un poco de historia nos lleva a que Git es un software de control de versiones diseñado por Linus Torvalds, pensando en la eficiencia, la confiabilidad y compatibilidad del mantenimiento de versiones de aplicaciones cuando estas tienen un gran número de archivos de código fuente. Su propósito es llevar registro de los cambios en archivos de computadora incluyendo coordinar el trabajo que varias personas realizan sobre archivos compartidos en un repositorio de código.
#
# **Git** usa un tipo de modelado asiclico para modelar la historia, puede tener puntos de modificación paralelos, que parten de un mismo punto de la historia;  y luego estos dos nodos paralelos se pueden converger para unificar las modificaciones realizadas en cada uno de ellos.
#
# Git se basa en objetos, que usan una semilla, la cual contiene múltiples referencias de tipo inmutable con cada uno de los cambios realizados en cada uno de los snapshots.  Esas referencias no son modificables, y cualquier modificación crea un nuevo punto del objeto.
#
# Objetos que apuntan a una semilla,   los objetos y sus referencias son los dos componentes principales con los cuales trabaja Git,  concluyendo en referencias que pueden apuntar a un nodo en particular,  y podemos modificar, ya sea las referencias de los datos de los objetos o los datos de las referencias.
# Al usar el comando “git commit”  se crea un nodo con un identificador o identificador de la *“semilla”* ,  el otro comando importante es **“git add”** permite agregar punto a punto nuevos nodos con los cambios que se quieren únicamente, y todo lo que se encontraba nuevo desde el último snapshot
# **“Git log”**  permite visualizar la historia de las versiones,  muestra un resumen de las versiones.  Pero para tener una mejor visión de esto es mejor usar **“Git log  - - all  - -graph  - - decorate”**
#
# La referencia **“HEAD”**  hace alusión al lugar que estamos apuntando,  por ejemplo una carpeta o repositorio con nombre Master
#
# #### Github es un host repositorio para Git
#
# GitHub es una plataforma de desarrollo colaborativo para alojar proyectos utilizando el sistema de control de versiones Git. Se utiliza principalmente para la creación de código fuente de programas de ordenador. El software que opera GitHub fue escrito en Ruby on Rails.
#
# Algunos comandos usados entre para interactuar entre *GIT* y *GITHUB* son:
#
# 1. Branching and Merging
# 	Hay que expandir en función al lo explicado
# 2. Git remote
# 	Se crea un directorio  “mkdir #nombre”
# 	Cambiamos al directorio “cd #nombre”
# 	Git init   - -  bare
# 	Se pueden crear Branches en el repositorio “Remote” y colaborar desde allí
# 3. Git push
# 		Enviar el cambio realizado al master remoto.   Fast forward
# 4. Git fetch <remote>
# 		Actualiza y nos dice los cambios que se han dado en el repositorio
# 5. Git merge
# 		Une los branch
# 6. Git config command
# 7. Git clone
# 		Copia la historia completa del repositorio remoto
# 8. Git clone - - shallow
# 		Copia el ultimo snapshot
# 9. Git blame
# 		Es un resumen del loggin en función de los cambios en el código
# 10. Git stash
# 		Revierte el ultimo cambio realizado
# 11. Git bisect
# 		Sirve para encontrar en la historia, el último cambio previo a que dejara de correr 		el código o se presentara un problema
#
# 12. git commit
#         Agrega una modificación y la traslada al nodo
# 13. git add
#         Agrega una modificación o nodo
# 14. git log  - - all - -  graph - - decorate
#         Muestra el log de los cambios realizados
# 15. git checkout #hash
#         Nos muestra una versión anterior requerida según un # hash
# 16. git diff #hash
#         Muestra los cambio (inclusiones o remosiones) realizadas en ese #hash
# 17. git status
# 18. git branch #name
#         crea un nodo paralelo y el puntero apunta al nodo actual y a este nodo
#
#
#
# Fuentes de información:
# * https://missing.csail.mit.edu/2020/version-control/
#
# * https://sqlbak.com/blog/wp-content/uploads/2020/12/Jupyter-Notebook-Markdown-Cheatsheet2.pdf
#
# * https://mljar.com/blog/jupyter-notebook-insert-image/
#
# * https://es.wikipedia.org/wiki/GitHub

# %% [markdown]
# ![logo.jpg](attachment:logo.jpg)
